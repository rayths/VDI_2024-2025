# %% [markdown]
# # Analisis Visualisasi Perbandingan Jenis Wisata di Delapan Kota: Tren Kunjungan, Popularitas, dan Wishlist Pengunjung

# %% [markdown]
# **Anggota Kelompok:**
# 1. Raid Muhammad Naufal 	(122450027)
# 2. Khusnun Nisa 		      (122450078)
# 3. Elisabeth Claudia S. 	(122450123)

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import urllib.parse
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from branca.element import Template, MacroElement

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import Dataset dan Menggabungkan Data

# %% [markdown]
# ### Import POI List
#
# Buda = Budapest\
# Delh = Delhi\
# Edin = Edinburgh\
# Glas = Glasgow\
# Osak = Osaka\
# Pert = Perth\
# Toro = Toronto\
# Vien = Vienna

# %%
# Import semua dataset POI List untuk ke delapan kota
POI_Buda = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Buda.csv', sep=';')
POI_Delh = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Delh.csv', sep=';')
POI_Edin = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Edin.csv', sep=';')
POI_Glas = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Glas.csv', sep=';')
POI_Osak = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Osak.csv', sep=';')
POI_Pert = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Pert.csv', sep=';')
POI_Toro = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Toro.csv', sep=';')
POI_Vien = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/poiList-ijcai15/POI-Vien.csv', sep=';')

# %%
POI_Buda.head()
# Out:
#    poiID                      poiName        lat       long       theme
# 0      1           S%C3%A1ndor_Palace  47.497800  19.037800  Historical
# 1      2     Ervin_Szab%C3%B3_Library  47.489378  19.064800  Historical
# 2      3               Gresham_Palace  47.499747  19.047981  Historical
# 3      4                  Buda_Castle  47.496110  19.039720  Historical
# 4      5  Hungarian_State_Opera_House  47.502808  19.058189    Cultural

# %%
POI_Delh.head()
# Out:
#    poiID                     poiName        lat       long     theme
# 0      1                  India_Gate  28.612864  77.229306  Building
# 1      2               Sansad_Bhavan  28.617189  77.208084  Building
# 2      3          Rashtrapati_Bhavan  28.614342  77.199803  Building
# 3      4  Connaught_Place,_New_Delhi  28.632780  77.219720      Park
# 4      5               Lodhi_Gardens  28.593000  77.220000      Park

# %%
POI_Edin.head()
# Out:
#    poiID                       poiName        lat      long       theme
# 0      1              Edinburgh_Castle  55.948611 -3.200833  Historical
# 1      2               Holyrood_Palace  55.952500 -3.172500  Historical
# 2      3   National_Museum_of_Scotland  55.946940 -3.190000      Museum
# 3      4  Scottish_Parliament_Building  55.952158 -3.175204   Structure
# 4      5             Forth_Rail_Bridge  56.000421 -3.388726   Structure

# %%
POI_Glas.head()
# Out:
#    poiID                                  poiName       lat     long  \
# 0      1          Glasgow_Central_railway_station  55.85800 -4.25800
# 1      2     Glasgow_Queen_Street_railway_station  55.86220 -4.25120
# 2      3                          Glasgow_Airport  55.87194 -4.43306
# 3      4  Glasgow_Prestwick_International_Airport  55.50944 -4.59444
# 4      5                             Clyde_Tunnel  55.86867 -4.33115
#
#        theme
# 0  Transport
# 1  Transport
# 2  Transport
# 3  Transport
# 4  Transport

# %%
POI_Osak.head()
# Out:
#    poiID                  poiName        lat        long      theme
# 0      1  Osaka_Aquarium_Kaiyukan  34.654472  135.428889  Amusement
# 1      2    Tempozan_Ferris_Wheel  34.656166  135.431031  Amusement
# 2      3         Tenn%C5%8Dji_Zoo  34.652556  135.508496  Amusement
# 3      4  Universal_Studios_Japan  34.664720  135.433060  Amusement
# 4      5                 HEP_Five  34.704003  135.500447  Amusement

# %%
POI_Pert.head()
# Out:
#    poiID                             poiName        lat        long      theme
# 0      1                     Perth_Town_Hall -31.955000  115.860556  Structure
# 1      2             Parliament_House,_Perth -31.951634  115.847209  Structure
# 2      3  State_Library_of_Western_Australia -31.949031  115.860513  Structure
# 3      4                    Chinatown,_Perth -31.946000  115.854000   Precinct
# 4      5      Northbridge,_Western_Australia -31.946000  115.854000   Precinct

# %%
POI_Toro.head()
# Out:
#    poiID             poiName        lat       long  theme
# 0      1   Air_Canada_Centre  43.643330 -79.379170  Sport
# 1      2           BMO_Field  43.632780 -79.418610  Sport
# 2      3  Maple_Leaf_Gardens  43.662220 -79.380280  Sport
# 3      4       Rogers_Centre  43.641390 -79.389170  Sport
# 4      5  Woodbine_Racetrack  43.712525 -79.602042  Sport

# %%
POI_Vien.head()
# Out:
#    poiID                     poiName        lat       long          theme
# 0      1      Sch%C3%B6nbrunn_Palace  48.184516  16.311865         Palace
# 1      2  Tiergarten_Sch%C3%B6nbrunn  48.182220  16.302500            Zoo
# 2      3            Wiener_Riesenrad  48.216651  16.395949  Entertainment
# 3      4           Albertina,_Vienna  48.204440  16.367780         Museum
# 4      5              Hofburg_Palace  48.206507  16.365262         Palace

# %% [markdown]
# ### Deskripsi Dataset POI List

# %%
def count_unique_values(df):
  print(f"\nNumber of rows: {df.shape[0]}")
  print(f"Number of columns: {df.shape[1]}")
  print(f"Column names: {df.columns.tolist()}")
  for col in df.columns:
    print(f"Column '{col}': {df[col].nunique()} unique values")


count_unique_values(POI_Buda)
count_unique_values(POI_Delh)
count_unique_values(POI_Edin)
count_unique_values(POI_Glas)
count_unique_values(POI_Osak)
count_unique_values(POI_Pert)
count_unique_values(POI_Toro)
count_unique_values(POI_Vien)
# Out:
# Number of rows: 39
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 39 unique values
# Column 'poiName': 39 unique values
# Column 'lat': 37 unique values
# Column 'long': 38 unique values
# Column 'theme': 6 unique values
#
# Number of rows: 26
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 26 unique values
# Column 'poiName': 26 unique values
# Column 'lat': 26 unique values
# Column 'long': 26 unique values
# Column 'theme': 6 unique values
#
# Number of rows: 29
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 29 unique values
# Column 'poiName': 29 unique values
# Column 'lat': 28 unique values
# Column 'long': 28 unique values
# Column 'theme': 6 unique values
#
# Number of rows: 29
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 29 unique values
# Column 'poiName': 29 unique values
# Column 'lat': 28 unique values
# Column 'long': 29 unique values
# Column 'theme': 7 unique values
#
# Number of rows: 29
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 29 unique values
# Column 'poiName': 28 unique values
# Column 'lat': 28 unique values
# Column 'long': 28 unique values
# Column 'theme': 4 unique values
#
# Number of rows: 25
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 25 unique values
# Column 'poiName': 25 unique values
# Column 'lat': 23 unique values
# Column 'long': 24 unique values
# Column 'theme': 8 unique values
#
# Number of rows: 30
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 30 unique values
# Column 'poiName': 30 unique values
# Column 'lat': 28 unique values
# Column 'long': 29 unique values
# Column 'theme': 6 unique values
#
# Number of rows: 29
# Number of columns: 5
# Column names: ['poiID', 'poiName', 'lat', 'long', 'theme']
# Column 'poiID': 29 unique values
# Column 'poiName': 28 unique values
# Column 'lat': 26 unique values
# Column 'long': 28 unique values
# Column 'theme': 8 unique values

# %%
POI_Osak
# Out:
#     poiID                          poiName        lat        long  \
# 0       1          Osaka_Aquarium_Kaiyukan  34.654472  135.428889
# 1       2            Tempozan_Ferris_Wheel  34.656166  135.431031
# 2       3                 Tenn%C5%8Dji_Zoo  34.652556  135.508496
# 3       4          Universal_Studios_Japan  34.664720  135.433060
# 4       5                         HEP_Five  34.704003  135.500447
# 5       6               Umeda_Sky_Building  34.705280  135.489720
# 6       7                 Nakanoshima_Park  34.693056  135.506431
# 7       8                     Osaka_Castle  34.687220  135.525830
# 8       9                   Sumiyoshi_Park  34.612400  135.488480
# 9      10                Tenn%C5%8Dji_Park  34.649850  135.511110
# 10     11                      Utsubo_Park  34.685055  135.492786
# 11     12                       Nagai_Park  34.611940  135.520560
# 12     13                     Osaka_Castle  34.687220  135.525830
# 13     14                Sank%C5%8D_Shrine  34.673060  135.529440
# 14     15                 Shitenn%C5%8D-ji  34.653900  135.516450
# 15     16                 Sumiyoshi_taisha  34.612797  135.492942
# 16     17         Tamatsukuri_Inari_Shrine  34.678060  135.530000
# 17     18  %C5%8Csaka_Tenmang%C5%AB_Shrine  34.696025  135.512619
# 18     19                   D%C5%8Dtonbori  34.668507  135.480684
# 19     20                            Namba  34.667220  135.500280
# 20     21                     Shinsaibashi  34.672500  135.500000
# 21     22                        Shinsekai  34.652220  135.506110
# 22     23                      Nipponbashi  34.659720  135.505830
# 23     24                      Amerikamura  34.672086  135.497960
# 24     25                   J%C5%ABs%C5%8D  34.719710  135.482755
# 25     26              Ky%C5%8Dbashi#Osaka  35.675178  139.769294
# 26     27                             Zepp  34.657361  135.501306
# 27     28             Doyama,_Osaka,_Japan  34.703165  135.502882
# 28     29                   Tobita_Shinchi  34.644325  135.505444
#
#             theme
# 0       Amusement
# 1       Amusement
# 2       Amusement
# 3       Amusement
# 4       Amusement
# 5       Amusement
# 6            Park
# 7            Park
# 8            Park
# 9            Park
# 10           Park
# 11           Park
# 12     Historical
# 13     Historical
# 14     Historical
# 15     Historical
# 16     Historical
# 17     Historical
# 18  Entertainment
# 19  Entertainment
# 20  Entertainment
# 21  Entertainment
# 22  Entertainment
# 23  Entertainment
# 24  Entertainment
# 25  Entertainment
# 26  Entertainment
# 27  Entertainment
# 28  Entertainment

# %%
POI_Osak['poiName'].value_counts()
# Out:
# poiName
# Osaka_Castle                       2
# Osaka_Aquarium_Kaiyukan            1
# Tamatsukuri_Inari_Shrine           1
# Doyama,_Osaka,_Japan               1
# Zepp                               1
# Ky%C5%8Dbashi#Osaka                1
# J%C5%ABs%C5%8D                     1
# Amerikamura                        1
# Nipponbashi                        1
# Shinsekai                          1
# Shinsaibashi                       1
# Namba                              1
# D%C5%8Dtonbori                     1
# %C5%8Csaka_Tenmang%C5%AB_Shrine    1
# Sumiyoshi_taisha                   1
# Tempozan_Ferris_Wheel              1
# Shitenn%C5%8D-ji                   1
# Sank%C5%8D_Shrine                  1
# Nagai_Park                         1
# Utsubo_Park                        1
# Tenn%C5%8Dji_Park                  1
# Sumiyoshi_Park                     1
# Nakanoshima_Park                   1
# Umeda_Sky_Building                 1
# HEP_Five                           1
# Universal_Studios_Japan            1
# Tenn%C5%8Dji_Zoo                   1
# Tobita_Shinchi                     1
# Name: count, dtype: int64

# %% [markdown]
# ### Import User Visits

# %%
# Import semua dataset User Visits pada delapan kota
user_visits_Buda = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Buda-allPOI.csv', sep=';')
user_visits_Delh = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Delh-allPOI.csv', sep=';')
user_visits_Edin = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Edin.csv', sep=';')
user_visits_Glas = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Glas.csv', sep=';')
user_visits_Osak = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Osak.csv', sep=';')
user_visits_Pert = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Pert-allPOI.csv', sep=';')
user_visits_Toro = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Toro.csv', sep=';')
user_visits_Vien = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/userVisits-ijcai15/userVisits-Vien-allPOI.csv', sep=';')

# %% [markdown]
# ### Deskripsi Dataset User Visits

# %%
user_visits_Buda.head()
# Out:
#        photoID         userID   dateTaken  poiID    poiTheme  poiFreq  seqID
# 0   5528931997   10088550@N00  1299815700     14   Transport      450      1
# 1   3563396553   10131865@N02  1243168517     29      Museum      587      2
# 2   3564212768   10131865@N02  1243168542     29      Museum      587      2
# 3   9800881585  101655764@N06  1370007538      3  Historical      859      3
# 4  12542876345  101655764@N06  1370008356     14   Transport      450      3

# %%
user_visits_Delh.head()
# Out:
#       photoID        userID   dateTaken  poiID       poiTheme  poiFreq  seqID
# 0  8636126004  10126637@N02  1365314352     12  Architectural      709      1
# 1  8635021631  10126637@N02  1365314896     11  Architectural      418      1
# 2  7133494159  10216976@N05  1332119449     18      Religious      534      2
# 3  7133492891  10216976@N05  1332119539     18      Religious      534      2
# 4  7909379802  10297667@N06  1255940392     18      Religious      534      3

# %%
user_visits_Edin.head()
# Out:
#       photoID        userID   dateTaken  poiID   poiTheme  poiFreq  seqID
# 0   355803498  10063645@N00  1168492531     17  Structure     1303      1
# 1   355803564  10063645@N00  1168492549     17  Structure     1303      1
# 2   355803639  10063645@N00  1168492558     17  Structure     1303      1
# 3  1431486935  10091295@N02  1190421746     12   Cultural     1208      2
# 4  1432364530  10091295@N02  1190421792     12   Cultural     1208      2

# %%
user_visits_Glas.head()
# Out:
#      photoID        userID   dateTaken  poiID   poiTheme  poiFreq  seqID
# 0  268535960  10063645@N00  1160716026     11  Education     1008      1
# 1  284505324  10063645@N00  1162247008      2  Transport      916      2
# 2  285538933  10063645@N00  1162333588     11  Education     1008      3
# 3  289494173  10063645@N00  1162693595     16   Shopping      848      4
# 4  289494204  10063645@N00  1162693817     21     Museum      618      4

# %%
user_visits_Osak.head()
# Out:
#       photoID        userID   dateTaken  poiID       poiTheme  poiFreq  seqID
# 0  6656416589  10297518@N00  1277719324     20  Entertainment      514      1
# 1  6656418463  10297518@N00  1277719344     20  Entertainment      514      1
# 2  6656420371  10297518@N00  1277719541     20  Entertainment      514      1
# 3  6656421479  10297518@N00  1277719558     20  Entertainment      514      1
# 4  6656422763  10297518@N00  1277719573     20  Entertainment      514      1

# %%
user_visits_Pert.head()
# Out:
#       photoID        userID   dateTaken  poiID       poiTheme  poiFreq  seqID
# 0  7158915820  11146442@N00  1336155672      1      Structure      256      1
# 1  7158914400  11146442@N00  1336156397      7           Park      329      1
# 2  7158907712  11146442@N00  1336157902      7           Park      329      1
# 3  7158905954  11146442@N00  1336158437      6           Park      500      1
# 4  7158899778  11146442@N00  1336170989     23  Entertainment      128      1

# %%
user_visits_Toro.head()
# Out:
#       photoID        userID   dateTaken  poiID   poiTheme  poiFreq  seqID
# 0  7941504100  10007579@N00  1346844688     30  Structure     1538      1
# 1  4886005532  10012675@N05  1142731848      6   Cultural      986      2
# 2  4886006468  10012675@N05  1142732248      6   Cultural      986      2
# 3  4885404441  10012675@N05  1142732373      6   Cultural      986      2
# 4  4886008334  10012675@N05  1142732445      6   Cultural      986      2

# %%
user_visits_Vien.head()
# Out:
#       photoID        userID   dateTaken  poiID   poiTheme  poiFreq  seqID
# 0  8703140158  10002536@N02  1367146438      8  Structure      571      1
# 1  8703142404  10002536@N02  1367146924      8  Structure      571      1
# 2  8703142278  10002536@N02  1367147103      8  Structure      571      1
# 3  8702020493  10002536@N02  1367147154      8  Structure      571      1
# 4  3074192212  10014440@N06  1227393491      5     Palace     1750      2

# %%
count_unique_values(user_visits_Buda)
count_unique_values(user_visits_Delh)
count_unique_values(user_visits_Edin)
count_unique_values(user_visits_Glas)
count_unique_values(user_visits_Osak)
count_unique_values(user_visits_Pert)
count_unique_values(user_visits_Toro)
count_unique_values(user_visits_Vien)
# Out:
# Number of rows: 18513
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 18513 unique values
# Column 'userID': 935 unique values
# Column 'dateTaken': 18094 unique values
# Column 'poiID': 38 unique values
# Column 'poiTheme': 6 unique values
# Column 'poiFreq': 37 unique values
# Column 'seqID': 2361 unique values
#
# Number of rows: 3993
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 3993 unique values
# Column 'userID': 279 unique values
# Column 'dateTaken': 3920 unique values
# Column 'poiID': 23 unique values
# Column 'poiTheme': 6 unique values
# Column 'poiFreq': 22 unique values
# Column 'seqID': 489 unique values
#
# Number of rows: 33944
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 33944 unique values
# Column 'userID': 1454 unique values
# Column 'dateTaken': 33229 unique values
# Column 'poiID': 28 unique values
# Column 'poiTheme': 6 unique values
# Column 'poiFreq': 28 unique values
# Column 'seqID': 5028 unique values
#
# Number of rows: 11434
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 11434 unique values
# Column 'userID': 601 unique values
# Column 'dateTaken': 10780 unique values
# Column 'poiID': 27 unique values
# Column 'poiTheme': 7 unique values
# Column 'poiFreq': 26 unique values
# Column 'seqID': 2227 unique values
#
# Number of rows: 7747
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 7747 unique values
# Column 'userID': 450 unique values
# Column 'dateTaken': 7476 unique values
# Column 'poiID': 27 unique values
# Column 'poiTheme': 4 unique values
# Column 'poiFreq': 26 unique values
# Column 'seqID': 1115 unique values
#
# Number of rows: 3643
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 3643 unique values
# Column 'userID': 159 unique values
# Column 'dateTaken': 3620 unique values
# Column 'poiID': 22 unique values
# Column 'poiTheme': 7 unique values
# Column 'poiFreq': 21 unique values
# Column 'seqID': 716 unique values
#
# Number of rows: 39419
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 39419 unique values
# Column 'userID': 1395 unique values
# Column 'dateTaken': 38677 unique values
# Column 'poiID': 29 unique values
# Column 'poiTheme': 6 unique values
# Column 'poiFreq': 29 unique values
# Column 'seqID': 6057 unique values
#
# Number of rows: 34515
# Number of columns: 7
# Column names: ['photoID', 'userID', 'dateTaken', 'poiID', 'poiTheme', 'poiFreq', 'seqID']
# Column 'photoID': 34515 unique values
# Column 'userID': 1155 unique values
# Column 'dateTaken': 33509 unique values
# Column 'poiID': 28 unique values
# Column 'poiTheme': 8 unique values
# Column 'poiFreq': 27 unique values
# Column 'seqID': 3193 unique values

# %% [markdown]
# ### Import Cost Prof

# %%
cost_prof_Buda = pd.read_csv('/content/drive/MyDrive/Tubes/VDI/data-ijcai15/costProf-ijcai15/costProfCat-BudaPOI-all.csv', sep=';')

cost_prof_Buda
# Out:
#       from  to          cost  profit    category
# 0        1   2   2236.791812      83  Historical
# 1        1   3    795.755249     859  Historical
# 2        1   4    237.161458     895  Historical
# 3        1   5   1631.576376     552    Cultural
# 4        1   6   2303.468537     472      Museum
# ...    ...  ..           ...     ...         ...
# 1401    39  34   4528.343305       2        Park
# 1402    39  35   1228.431865     192        Park
# 1403    39  36  10387.524535     894      Museum
# 1404    39  37   1690.465458     785   Transport
# 1405    39  38   1887.754489     279    Shopping
#
# [1406 rows x 5 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Menggabungkan POI List Masing-Masing Kota

# %%
# Membuat list untuk menyimpan seluruh dataframe POI List
dfs = [POI_Buda, POI_Delh, POI_Edin, POI_Glas, POI_Osak, POI_Pert, POI_Toro, POI_Vien]

# Membuat list untuk menyimpan nama-nama kota
cities = ['Budapest', 'Delhi', 'Edinburgh', 'Glasgow', 'Osaka', 'Perth', 'Toronto', 'Vienna']

# Membuat list kosong untuk menyimpan data gabungan
combined_data = []

# Perulangan berdasarkan dataframe dan nama kota
for i, df in enumerate(dfs):
    # Menambahkan kolom 'city' ke dataframe
    df['city'] = cities[i]
    # Menambahkan dataframe dengan nama kota ke list data gabungan
    combined_data.append(df)

# Menggabungkan dataframe dalam list data gabungan menjadi satu dataframe
POI_List = pd.concat(combined_data, ignore_index=True)

# Menampilkan sample dari dataframe
POI_List.sample(20)
# Out:
#      poiID                         poiName        lat        long  \
# 11      12              Vajdahunyad_Castle  47.515280   19.081940
# 150     28            Doyama,_Osaka,_Japan  34.703165  135.502882
# 206     30         Union_Station_(Toronto)  43.645280  -79.380560
# 27      28         Szabads%C3%A1g_t%C3%A9r  47.504720   19.050280
# 17      18          Gell%C3%A9rt_Hill_Cave  47.485106   19.051978
# 37      38                  V%C3%A1ci_utca  47.494222   19.052425
# 189     13                       Casa_Loma  43.678100  -79.409500
# 14      15    Franz_Liszt_Academy_of_Music  47.503247   19.064517
# 32      33      Saint_Stephen%27s_Basilica  47.500833   19.053889
# 226     20  St._Charles%27s_Church,_Vienna  48.198333   16.371389
# 185      9          Ontario_Science_Centre  43.716670  -79.338330
# 197     21             Yonge-Dundas_Square  43.656110  -79.380280
# 168     17           Perth_railway_station -31.951493  115.860448
# 170     19               Esplanade_Busport -31.956200  115.854650
# 118     25     Glasgow_Museum_of_Transport  55.868700   -4.295000
# 113     20      Glasgow_Royal_Concert_Hall  55.864503   -4.252921
# 143     21                    Shinsaibashi  34.672500  135.500000
# 86      22                      Bute_House  55.952531   -3.208017
# 215      9        Naturhistorisches_Museum  48.205200   16.359900
# 147     25                  J%C5%ABs%C5%8D  34.719710  135.482755
#
#              theme       city
# 11      Historical   Budapest
# 150  Entertainment      Osaka
# 206      Structure    Toronto
# 27            Park   Budapest
# 17            Park   Budapest
# 37        Shopping   Budapest
# 189       Cultural    Toronto
# 14        Cultural   Budapest
# 32        Cultural   Budapest
# 226     Historical     Vienna
# 185       Cultural    Toronto
# 197          Beach    Toronto
# 168      Transport      Perth
# 170      Transport      Perth
# 118         Museum    Glasgow
# 113      Structure    Glasgow
# 143  Entertainment      Osaka
# 86       Structure  Edinburgh
# 215         Museum     Vienna
# 147  Entertainment      Osaka

# %%
# Filter data dengan POI ID 1 dan 2
filtered_data = POI_List[POI_List['poiID'].isin([1, 2])]

filtered_data
# Out:
#      poiID                               poiName        lat        long  \
# 0        1                    S%C3%A1ndor_Palace  47.497800   19.037800
# 1        2              Ervin_Szab%C3%B3_Library  47.489378   19.064800
# 39       1                            India_Gate  28.612864   77.229306
# 40       2                         Sansad_Bhavan  28.617189   77.208084
# 65       1                      Edinburgh_Castle  55.948611   -3.200833
# 66       2                       Holyrood_Palace  55.952500   -3.172500
# 94       1       Glasgow_Central_railway_station  55.858000   -4.258000
# 95       2  Glasgow_Queen_Street_railway_station  55.862200   -4.251200
# 123      1               Osaka_Aquarium_Kaiyukan  34.654472  135.428889
# 124      2                 Tempozan_Ferris_Wheel  34.656166  135.431031
# 152      1                       Perth_Town_Hall -31.955000  115.860556
# 153      2               Parliament_House,_Perth -31.951634  115.847209
# 177      1                     Air_Canada_Centre  43.643330  -79.379170
# 178      2                             BMO_Field  43.632780  -79.418610
# 207      1                Sch%C3%B6nbrunn_Palace  48.184516   16.311865
# 208      2            Tiergarten_Sch%C3%B6nbrunn  48.182220   16.302500
#
#           theme       city
# 0    Historical   Budapest
# 1    Historical   Budapest
# 39     Building      Delhi
# 40     Building      Delhi
# 65   Historical  Edinburgh
# 66   Historical  Edinburgh
# 94    Transport    Glasgow
# 95    Transport    Glasgow
# 123   Amusement      Osaka
# 124   Amusement      Osaka
# 152   Structure      Perth
# 153   Structure      Perth
# 177       Sport    Toronto
# 178       Sport    Toronto
# 207      Palace     Vienna
# 208         Zoo     Vienna

# %%
POI_List.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   poiID    236 non-null    int64
#  1   poiName  236 non-null    object
#  2   lat      236 non-null    float64
#  3   long     236 non-null    float64
#  4   theme    236 non-null    object
#  5   city     236 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 11.2+ KB

# %%
POI_List.head(10)
# Out:
#    poiID                               poiName        lat       long  \
# 0      1                    S%C3%A1ndor_Palace  47.497800  19.037800
# 1      2              Ervin_Szab%C3%B3_Library  47.489378  19.064800
# 2      3                        Gresham_Palace  47.499747  19.047981
# 3      4                           Buda_Castle  47.496110  19.039720
# 4      5           Hungarian_State_Opera_House  47.502808  19.058189
# 5      6                       House_of_Terror  47.506940  19.065280
# 6      7  National_Sz%C3%A9ch%C3%A9nyi_Library  47.495000  19.039170
# 7      8                       Matthias_Church  47.501940  19.034170
# 8      9                 Fisherman%27s_Bastion  47.501670  19.035000
# 9     10                  City_Park_(Budapest)  47.513890  19.084720
#
#         theme      city
# 0  Historical  Budapest
# 1  Historical  Budapest
# 2  Historical  Budapest
# 3  Historical  Budapest
# 4    Cultural  Budapest
# 5      Museum  Budapest
# 6  Historical  Budapest
# 7    Cultural  Budapest
# 8  Historical  Budapest
# 9        Park  Budapest

# %% [markdown]
# ### Decoding poiName

# %%
# Decode URL-encoded values dalam kolom 'poiName'
POI_List['poiName'] = POI_List['poiName'].apply(lambda x: urllib.parse.unquote(x))

POI_List.head(10)
# Out:
#    poiID                      poiName        lat       long       theme  \
# 0      1                Sándor_Palace  47.497800  19.037800  Historical
# 1      2          Ervin_Szabó_Library  47.489378  19.064800  Historical
# 2      3               Gresham_Palace  47.499747  19.047981  Historical
# 3      4                  Buda_Castle  47.496110  19.039720  Historical
# 4      5  Hungarian_State_Opera_House  47.502808  19.058189    Cultural
# 5      6              House_of_Terror  47.506940  19.065280      Museum
# 6      7   National_Széchényi_Library  47.495000  19.039170  Historical
# 7      8              Matthias_Church  47.501940  19.034170    Cultural
# 8      9          Fisherman's_Bastion  47.501670  19.035000  Historical
# 9     10         City_Park_(Budapest)  47.513890  19.084720        Park
#
#        city
# 0  Budapest
# 1  Budapest
# 2  Budapest
# 3  Budapest
# 4  Budapest
# 5  Budapest
# 6  Budapest
# 7  Budapest
# 8  Budapest
# 9  Budapest

# %%
POI_List.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   poiID    236 non-null    int64
#  1   poiName  236 non-null    object
#  2   lat      236 non-null    float64
#  3   long     236 non-null    float64
#  4   theme    236 non-null    object
#  5   city     236 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 11.2+ KB

# %% [markdown]
# ### Menggabungkan User Visit Masing-Masing Kota

# %%
# Membuat list untuk menyimpan seluruh dataframe user visits
users = [user_visits_Buda, user_visits_Delh, user_visits_Edin, user_visits_Glas, user_visits_Osak, user_visits_Pert, user_visits_Toro, user_visits_Vien]

# Membuat list untuk menyimpan nama-nama kota
cities = ['Budapest', 'Delhi', 'Edinburgh', 'Glasgow', 'Osaka', 'Perth', 'Toronto', 'Vienna']

# Membuat list kosong untuk menyimpan data gabungan
combined_data = []

# Perulangan berdasarkan dataframe dan nama kota
for i, df in enumerate(users):
    # Menambahkan kolom 'city' ke dataframe
    df['city'] = cities[i]
    # Menambahkan dataframe dengan nama kota ke list data gabungan
    combined_data.append(df)

# Menggabungkan dataframe dalam list data gabungan menjadi satu dataframe
user_visits = pd.concat(combined_data, ignore_index=True)

# Menampilkan sample dari dataframe
user_visits.sample(20)
# Out:
#             photoID           userID   dateTaken  poiID       poiTheme  \
# 74707    9561572470     91609485@N00  1376276067      1      Amusement
# 103876   5901562886     57756296@N06  1309500636      2          Sport
# 24729    3695338799     14057878@N00  1245842092     29      Structure
# 24917    5884996238     14057878@N00  1308909410     19      Structure
# 36215    5507060319  41894148532@N01  1299199368      3         Museum
# 20649    1083475653     53493424@N00  1184401345     19      Religious
# 10380    3871476261  49503025036@N01  1178023634     33       Cultural
# 88601    4621655654     30129139@N04  1273917152     22          Beach
# 140597   2269203423     51159953@N00  1184976624      7         Palace
# 117107   6432074657     94064020@N00  1322602106      3          Sport
# 131492   7249216996     31403562@N00  1337653550     16         Museum
# 140472   4514059192     50403068@N00  1268868940      7         Palace
# 71308   10963391626     52043939@N00  1384742495      1      Amusement
# 131637   7366250754     31403562@N00  1339034659     11         Museum
# 16351    8352282051     87845387@N00  1338175270      8       Cultural
# 47013    7728369796      7512717@N06  1344223354     28      Structure
# 123955   3480990110     25507134@N00  1240731579      3  Entertainment
# 90222    3722169780     34211328@N00  1247202472     17      Amusement
# 96105    9266760223     43139087@N00  1370343094     27       Shopping
# 49094    1410165660      7856302@N02  1179857524      3         Museum
#
#         poiFreq  seqID       city
# 74707       886   1001      Osaka
# 103876      609   3779    Toronto
# 24729      2972    326  Edinburgh
# 24917      1559    338  Edinburgh
# 36215      3140   2219  Edinburgh
# 20649       206    246      Delhi
# 10380      1493   1295   Budapest
# 88601      3619   1543    Toronto
# 140597      539   1870     Vienna
# 117107      688   5712    Toronto
# 131492     4539   1057     Vienna
# 140472      539   1848     Vienna
# 71308       886    577      Osaka
# 131637     2802   1060     Vienna
# 16351      1584   2070   Budapest
# 47013      1325   3637  Edinburgh
# 123955     1243    638     Vienna
# 90222       808   1925    Toronto
# 96105       631   2773    Toronto
# 49094      3140   3970  Edinburgh

# %%
# Memfilter data dengan menampilkan 2 data teratas untuk setiap kota
filtered_data = user_visits.groupby('city').head(2)

filtered_data
# Out:
#            photoID        userID   dateTaken  poiID       poiTheme  poiFreq  \
# 0       5528931997  10088550@N00  1299815700     14      Transport      450
# 1       3563396553  10131865@N02  1243168517     29         Museum      587
# 18513   8636126004  10126637@N02  1365314352     12  Architectural      709
# 18514   8635021631  10126637@N02  1365314896     11  Architectural      418
# 22506    355803498  10063645@N00  1168492531     17      Structure     1303
# 22507    355803564  10063645@N00  1168492549     17      Structure     1303
# 56450    268535960  10063645@N00  1160716026     11      Education     1008
# 56451    284505324  10063645@N00  1162247008      2      Transport      916
# 67884   6656416589  10297518@N00  1277719324     20  Entertainment      514
# 67885   6656418463  10297518@N00  1277719344     20  Entertainment      514
# 75631   7158915820  11146442@N00  1336155672      1      Structure      256
# 75632   7158914400  11146442@N00  1336156397      7           Park      329
# 79274   7941504100  10007579@N00  1346844688     30      Structure     1538
# 79275   4886005532  10012675@N05  1142731848      6       Cultural      986
# 118693  8703140158  10002536@N02  1367146438      8      Structure      571
# 118694  8703142404  10002536@N02  1367146924      8      Structure      571
#
#         seqID       city
# 0           1   Budapest
# 1           2   Budapest
# 18513       1      Delhi
# 18514       1      Delhi
# 22506       1  Edinburgh
# 22507       1  Edinburgh
# 56450       1    Glasgow
# 56451       2    Glasgow
# 67884       1      Osaka
# 67885       1      Osaka
# 75631       1      Perth
# 75632       1      Perth
# 79274       1    Toronto
# 79275       2    Toronto
# 118693      1     Vienna
# 118694      1     Vienna

# %%
user_visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153208 entries, 0 to 153207
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   photoID    153208 non-null  int64
#  1   userID     153208 non-null  object
#  2   dateTaken  153208 non-null  int64
#  3   poiID      153208 non-null  int64
#  4   poiTheme   153208 non-null  object
#  5   poiFreq    153208 non-null  int64
#  6   seqID      153208 non-null  int64
#  7   city       153208 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 9.4+ MB

# %%
user_visits[(user_visits['city'] == 'Osaka') & (user_visits['poiID'] == 1)]
# Out:
#            photoID         userID   dateTaken  poiID   poiTheme  poiFreq  \
# 67920   8657549120   10340578@N06  1364432096      1  Amusement      886
# 67958  13502349575  115391424@N05  1395539024      1  Amusement      886
# 67959  13502349605  115391424@N05  1395539027      1  Amusement      886
# 67960  13502693544  115391424@N05  1395539028      1  Amusement      886
# 67961  13502349855  115391424@N05  1395539029      1  Amusement      886
# ...            ...            ...         ...    ...        ...      ...
# 75588   5101631973   97972855@N00  1287600841      1  Amusement      886
# 75589   5102252342   97972855@N00  1287601780      1  Amusement      886
# 75590   5102271906   97972855@N00  1287602426      1  Amusement      886
# 75591   5101702747   97972855@N00  1287603192      1  Amusement      886
# 75592   5101724373   97972855@N00  1287603874      1  Amusement      886
#
#        seqID   city
# 67920      4  Osaka
# 67958     11  Osaka
# 67959     11  Osaka
# 67960     11  Osaka
# 67961     11  Osaka
# ...      ...    ...
# 75588   1104  Osaka
# 75589   1104  Osaka
# 75590   1104  Osaka
# 75591   1104  Osaka
# 75592   1104  Osaka
#
# [886 rows x 8 columns]

# %% [markdown]
# poiFreq sama dengan Frekuensi suatu poi dikunjungi. 886 = 886.

# %% [markdown]
# ### Menambahkan Kolom poiFreq ke dalam Dataframe POI_List

# %%
# Memfilter nilai poiFreq berdasarkan city dan poiID
def get_poi_freq(city, poi_id):
    # Mengambil nilai poiFreq untuk kombinasi city dan poiID tertentu
    freq = user_visits[(user_visits['city'] == city) & (user_visits['poiID'] == poi_id)]['poiFreq']
    return freq.values[0] if not freq.empty else 0  # Jika tidak ditemukan, kembalikan nilai 0

# Menambahkan nilai poiFreq ke dalam dataframe POI_List
POI_List['poiFreq'] = POI_List.apply(lambda row: get_poi_freq(row['city'], row['poiID']), axis=1)

# Menampilkan sampel data
POI_List.head(10)
# Out:
#    poiID                      poiName        lat       long       theme  \
# 0      1                Sándor_Palace  47.497800  19.037800  Historical
# 1      2          Ervin_Szabó_Library  47.489378  19.064800  Historical
# 2      3               Gresham_Palace  47.499747  19.047981  Historical
# 3      4                  Buda_Castle  47.496110  19.039720  Historical
# 4      5  Hungarian_State_Opera_House  47.502808  19.058189    Cultural
# 5      6              House_of_Terror  47.506940  19.065280      Museum
# 6      7   National_Széchényi_Library  47.495000  19.039170  Historical
# 7      8              Matthias_Church  47.501940  19.034170    Cultural
# 8      9          Fisherman's_Bastion  47.501670  19.035000  Historical
# 9     10         City_Park_(Budapest)  47.513890  19.084720        Park
#
#        city  poiFreq
# 0  Budapest     1020
# 1  Budapest       83
# 2  Budapest      859
# 3  Budapest      895
# 4  Budapest      552
# 5  Budapest      472
# 6  Budapest      305
# 7  Budapest     1584
# 8  Budapest      946
# 9  Budapest      152

# %%
POI_List.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   poiID    236 non-null    int64
#  1   poiName  236 non-null    object
#  2   lat      236 non-null    float64
#  3   long     236 non-null    float64
#  4   theme    236 non-null    object
#  5   city     236 non-null    object
#  6   poiFreq  236 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 13.0+ KB

# %% [markdown]
# #### Membandingkan poiFreq pada dataframe POI_List dengan Data Sebenarnya (user_visits)

# %%
POI_List[(POI_List['city'] == 'Osaka') & (POI_List['poiID'] == 27)]
# Out:
#      poiID poiName        lat        long          theme   city  poiFreq
# 149     27    Zepp  34.657361  135.501306  Entertainment  Osaka        3

# %%
user_visits[(user_visits['city'] == 'Osaka') & (user_visits['poiID'] == 27)]
# Out:
#           photoID        userID   dateTaken  poiID       poiTheme  poiFreq  \
# 68072  6619939051  12452841@N00  1325022901     27  Entertainment        3
# 68724  9739979702  22896220@N05  1378607535     27  Entertainment        3
# 69844  5342312561  40037997@N02  1294620713     27  Entertainment        3
#
#        seqID   city
# 68072     21  Osaka
# 68724    114  Osaka
# 69844    381  Osaka

# %% [markdown]
# ### Menghitung Kategori POI untuk Setiap Kota

# %%
# Menghitung kategori POI pada setiap kota
poi_theme_city = POI_List.groupby(['city', 'theme']).size().unstack(fill_value=0)

poi_theme_city
# Out:
# theme      Amusement  Architectural  Beach  Building  Cultural  Education  \
# city
# Budapest           0              0      0         0         6          0
# Delhi              0              8      0         3         0          0
# Edinburgh          0              0      0         0         3          0
# Glasgow            0              0      0         0         0          6
# Osaka              6              0      0         0         0          0
# Perth              0              0      2         0         2          0
# Toronto            5              0      4         0         8          0
# Vienna             0              0      0         0         1          0
#
# theme      Entertainment  Historical  Museum  Palace  Park  Precinct  \
# city
# Budapest               0           9       8       0    10         0
# Delhi                  0           0       2       0     4         1
# Edinburgh              1           5       4       0     4         0
# Glasgow                0           0       4       0     2         0
# Osaka                 11           6       0       0     6         0
# Perth                  3           0       0       0     6         2
# Toronto                0           0       0       0     0         0
# Vienna                 2           6      11       4     2         0
#
# theme      Religion  Religious  Shopping  Sport  Structure  Transport  Zoo
# city
# Budapest          0          0         2      0          0          4    0
# Delhi             0          8         0      0          0          0    0
# Edinburgh         0          0         0      0         12          0    0
# Glasgow           2          0         2      0          7          6    0
# Osaka             0          0         0      0          0          0    0
# Perth             0          0         0      2          3          5    0
# Toronto           0          0         5      5          3          0    0
# Vienna            0          0         0      0          1          0    2

# %%
poi_theme_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, Budapest to Vienna
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Amusement      8 non-null      int64
#  1   Architectural  8 non-null      int64
#  2   Beach          8 non-null      int64
#  3   Building       8 non-null      int64
#  4   Cultural       8 non-null      int64
#  5   Education      8 non-null      int64
#  6   Entertainment  8 non-null      int64
#  7   Historical     8 non-null      int64
#  8   Museum         8 non-null      int64
#  9   Palace         8 non-null      int64
#  10  Park           8 non-null      int64
#  11  Precinct       8 non-null      int64
#  12  Religion       8 non-null      int64
#  13  Religious      8 non-null      int64
#  14  Shopping       8 non-null      int64
#  15  Sport          8 non-null      int64
#  16  Structure      8 non-null      int64
#  17  Transport      8 non-null      int64
#  18  Zoo            8 non-null      int64
# dtypes: int64(19)
# memory usage: 1.2+ KB

# %% [markdown]
# ### Mencari Kategori POI Terbanyak pada Setiap Kota

# %%
# Menentukan nilai maksimum untuk setiap baris (kota)
max_values = poi_theme_city.max(axis=1)

# Menentukan kolom (kategori) dengan nilai maksimum di setiap baris
dominant_categories = poi_theme_city.apply(
    lambda row: list(row[row == max_values[row.name]].index), axis=1
)

# Membuat DataFrame untuk menyimpan hasil
dominant_categories_df = pd.DataFrame({
    'City': poi_theme_city.index,
    'Dominant Categories': dominant_categories
}).reset_index(drop=True)

# Menampilkan hasil
print(dominant_categories_df)

# Standarisasi kolom 'Dominant Categories'
dominant_categories_df['Dominant Categories'] = dominant_categories_df['Dominant Categories'].apply(
    lambda categories: ' & '.join(sorted(categories))
)

# Menampilkan hasil setelah standarisasi
print(dominant_categories_df)
# Out:
#         City         Dominant Categories
# 0   Budapest                      [Park]
# 1      Delhi  [Architectural, Religious]
# 2  Edinburgh                 [Structure]
# 3    Glasgow                 [Structure]
# 4      Osaka             [Entertainment]
# 5      Perth                      [Park]
# 6    Toronto                  [Cultural]
# 7     Vienna                    [Museum]
#         City        Dominant Categories
# 0   Budapest                       Park
# 1      Delhi  Architectural & Religious
# 2  Edinburgh                  Structure
# 3    Glasgow                  Structure
# 4      Osaka              Entertainment
# 5      Perth                       Park
# 6    Toronto                   Cultural
# 7     Vienna                     Museum

# %% [markdown]
# ## Visualisasi 1 (Stacked Bar)

# %%
# Menghitung persentase proposi kategori POI setiap kota
poi_theme_city_percentage = poi_theme_city.div(poi_theme_city.sum(axis=1), axis=0) * 100

poi_theme_city_percentage
# Out:
# theme      Amusement  Architectural      Beach   Building   Cultural  \
# city
# Budapest    0.000000       0.000000   0.000000   0.000000  15.384615
# Delhi       0.000000      30.769231   0.000000  11.538462   0.000000
# Edinburgh   0.000000       0.000000   0.000000   0.000000  10.344828
# Glasgow     0.000000       0.000000   0.000000   0.000000   0.000000
# Osaka      20.689655       0.000000   0.000000   0.000000   0.000000
# Perth       0.000000       0.000000   8.000000   0.000000   8.000000
# Toronto    16.666667       0.000000  13.333333   0.000000  26.666667
# Vienna      0.000000       0.000000   0.000000   0.000000   3.448276
#
# theme      Education  Entertainment  Historical     Museum     Palace  \
# city
# Budapest    0.000000       0.000000   23.076923  20.512821   0.000000
# Delhi       0.000000       0.000000    0.000000   7.692308   0.000000
# Edinburgh   0.000000       3.448276   17.241379  13.793103   0.000000
# Glasgow    20.689655       0.000000    0.000000  13.793103   0.000000
# Osaka       0.000000      37.931034   20.689655   0.000000   0.000000
# Perth       0.000000      12.000000    0.000000   0.000000   0.000000
# Toronto     0.000000       0.000000    0.000000   0.000000   0.000000
# Vienna      0.000000       6.896552   20.689655  37.931034  13.793103
#
# theme           Park  Precinct  Religion  Religious   Shopping      Sport  \
# city
# Budapest   25.641026  0.000000  0.000000   0.000000   5.128205   0.000000
# Delhi      15.384615  3.846154  0.000000  30.769231   0.000000   0.000000
# Edinburgh  13.793103  0.000000  0.000000   0.000000   0.000000   0.000000
# Glasgow     6.896552  0.000000  6.896552   0.000000   6.896552   0.000000
# Osaka      20.689655  0.000000  0.000000   0.000000   0.000000   0.000000
# Perth      24.000000  8.000000  0.000000   0.000000   0.000000   8.000000
# Toronto     0.000000  0.000000  0.000000   0.000000  16.666667  16.666667
# Vienna      6.896552  0.000000  0.000000   0.000000   0.000000   0.000000
#
# theme      Structure  Transport       Zoo
# city
# Budapest    0.000000  10.256410  0.000000
# Delhi       0.000000   0.000000  0.000000
# Edinburgh  41.379310   0.000000  0.000000
# Glasgow    24.137931  20.689655  0.000000
# Osaka       0.000000   0.000000  0.000000
# Perth      12.000000  20.000000  0.000000
# Toronto    10.000000   0.000000  0.000000
# Vienna      3.448276   0.000000  6.896552

# %%
# Membuat visualisasi stacked bar
ax = poi_theme_city_percentage.plot(
    kind='bar',
    stacked=True,
    figsize=(12, 7),
    colormap='tab20',  # Menggunakan colormap untuk warna kontras
    edgecolor='black'
)

# Menambahkan label, judul, dan lainnya
plt.title('Proporsi Kategori POI di Setiap Kota', fontsize=14, weight='bold')
plt.xlabel('Kota', fontsize=12)
plt.ylabel('Proporsi Kategori POI (%)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Kategori POI', bbox_to_anchor=(1.05, 1), loc='upper left')

# Menampilkan persentase nilai pada setiap segmen bar
for container in ax.containers:
    for bar in container:
        if bar.get_height() > 0:  # Hanya jika proporsi > 0
            height = bar.get_height()
            x = bar.get_x() + bar.get_width() / 2
            y = bar.get_y() + height / 2  # Posisi teks
            ax.text(x, y, f'{height:.1f}%', ha='center', va='center', fontsize=9)

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualisasi 2 (Entropy Bar Chart)

# %%
# Menghitung entropy untuk setiap kota
def calculate_entropy(row):
    proportions = row / row.sum()
    entropy = -np.nansum(proportions * np.log2(proportions + 1e-9))  # Menghindari log(0)
    return entropy

poi_theme_city["Entropy"] = poi_theme_city.apply(calculate_entropy, axis=1)

poi_theme_city["Entropy"]
# Out:
# city
# Budapest     2.432623
# Delhi        2.286790
# Edinburgh    2.258530
# Glasgow      2.627945
# Osaka        1.941323
# Perth        2.858689
# Toronto      2.520764
# Vienna       2.528204
# Name: Entropy, dtype: float64

# %%
# Membuat warna gradasi berdasarkan nilai entropy
colors = plt.cm.viridis(poi_theme_city["Entropy"] / poi_theme_city["Entropy"].max())

# Membuat visualisasi entropy
plt.figure(figsize=(12, 6))
bars = plt.bar(poi_theme_city.index, poi_theme_city["Entropy"], color=colors, edgecolor='black')

# Menambahkan grid horizontal
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Menambahkan anotasi nilai pada puncak setiap batang
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, f'{yval:.2f}', ha='center', fontsize=10, weight="bold")

# Menambahkan label dan judul
plt.xlabel("Kota", fontsize=12, labelpad=10)
plt.ylabel("Entropy", fontsize=12, labelpad=10)
plt.title("Entropy Distribusi Kategori POI di Setiap Kota", fontsize=14, pad=15, weight="bold")

# Menambahkan rotasi pada label sumbu x
plt.xticks(rotation=45, fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()

# Menampilkan grafik
plt.show()

# %% [markdown]
# ## Visualisasi 3 (Horizontal Bar Chart)

# %%
# Menghitung jumlah kunjungan untuk setiap kategori POI
total_visits_by_category = (
    POI_List.groupby('theme')['poiFreq']
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

total_visits_by_category
# Out:
#             theme  poiFreq
# 0      Historical    25286
# 1        Cultural    23758
# 2          Museum    21706
# 3       Structure    16950
# 4            Park    10062
# 5           Sport     7944
# 6       Amusement     7866
# 7        Shopping     7792
# 8           Beach     7413
# 9   Entertainment     5998
# 10      Transport     5032
# 11         Palace     3688
# 12      Education     3536
# 13  Architectural     1845
# 14            Zoo     1830
# 15      Religious      959
# 16       Precinct      640
# 17       Religion      564
# 18       Building      401

# %%
# Membuat visualisasi
plt.figure(figsize=(10, 6))

# Membuat barplot menggunakan seaborn untuk menampilkan jumlah kunjungan per kategori POI secara global
sns.barplot(
    data=total_visits_by_category,  # Dataframe yang berisi informasi total kunjungan per kategori POI
    x='poiFreq',  # Sumbu x merepresentasikan jumlah kunjungan (poiFreq)
    y='theme',  # Sumbu y merepresentasikan kategori POI (theme)
    palette='viridis'  # Menggunakan palet warna "viridis" untuk visualisasi
)

# Memberikan judul pada grafik
plt.title('Total Kunjungan Berdasarkan Kategori POI pada 8 Kota', fontsize=14, weight='bold')

# Memberikan label pada sumbu x dan y
plt.xlabel('Jumlah Kunjungan', fontsize=12)
plt.ylabel('Kategori POI', fontsize=12)

# Menambahkan grid pada sumbu x untuk membantu pembacaan nilai
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Menampilkan grafik
plt.show()
# Out:
# <ipython-input-423-665ed811a828>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## Visualisasi 4 (Map)

# %%
# Memfilter 1 POI dengan jumlah kunjungan terbanyak dari setiap kota
top_poi_per_city = POI_List.loc[POI_List.groupby('city')['poiFreq'].idxmax()]

top_poi_per_city
# Out:
#      poiID                          poiName        lat        long  \
# 7        8                  Matthias_Church  47.501940   19.034170
# 50      12                     Qutb_complex  28.524382   77.185430
# 65       1                 Edinburgh_Castle  55.948611   -3.200833
# 94       1  Glasgow_Central_railway_station  55.858000   -4.258000
# 130      8                     Osaka_Castle  34.687220  135.525830
# 157      6            Supreme_Court_Gardens -31.958500  115.859900
# 187     11             Royal_Ontario_Museum  43.667500  -79.394170
# 223     17  St._Stephen's_Cathedral,_Vienna  48.208500   16.373000
#
#              theme       city  poiFreq
# 7         Cultural   Budapest     1584
# 50   Architectural      Delhi      709
# 65      Historical  Edinburgh     4569
# 94       Transport    Glasgow     1491
# 130           Park      Osaka     1307
# 157           Park      Perth      500
# 187       Cultural    Toronto     4142
# 223     Historical     Vienna     5533

# %%
# Daftar warna untuk setiap kategori
theme_colors = {
    "Cultural": "purple",
    "Architectural": "grey",
    "Historical": "orange",
    "Transport": "lightblue",
    "Park": "green",
}

# Membuat peta interaktif dengan folium
poi_map = folium.Map(
    location=[top_poi_per_city['lat'].mean(), top_poi_per_city['long'].mean()],
    zoom_start=3
)

# Menambahkan marker untuk setiap POI
for _, row in top_poi_per_city.iterrows():
    theme_color = theme_colors.get(row['theme'], "gray")  # Default warna jika tema tidak terdaftar
    folium.Marker(
        location=[row['lat'], row['long']],
        popup=folium.Popup(
            f"<b>Nama:</b> {row['poiName']}<br>"
            f"<b>Kota:</b> {row['city']}<br>"
            f"<b>Tema:</b> {row['theme']}<br>"
            f"<b>Kunjungan:</b> {row['poiFreq']}",
            max_width=300
        ),
        tooltip=f"{row['poiName']} ({row['poiFreq']} kunjungan)",
        icon=folium.Icon(color=theme_color, icon='info-sign')
    ).add_to(poi_map)

# Menambahkan legenda ke peta
legend_html = """
<div style="position: fixed;
            bottom: 20px; left: 20px; width: 200px; height: 150px;
            background-color: white; z-index:9999; font-size:14px;
            border:2px solid grey; padding: 10px;">
<b>Legenda Kategori POI:</b><br>
"""
for cat, color in theme_colors.items():
  legend_html += f'<i style="background:{color}; width:12px; height:12px; display:inline-block;"></i> {cat}<br>'
legend_html += '</div>'
poi_map.get_root().html.add_child(folium.Element(legend_html))

# Menyimpan dan menampilkan peta
poi_map.save("top_poi_per_city_map.html")
poi_map
# Out:
# <ipython-input-422-603a774d0f6f>:29: UserWarning: color argument of Icon should be one of: {'lightblue', 'beige', 'blue', 'white', 'cadetblue', 'black', 'orange', 'darkpurple', 'gray', 'red', 'darkred', 'pink', 'lightred', 'darkgreen', 'lightgray', 'darkblue', 'lightgreen', 'green', 'purple'}.
#   icon=folium.Icon(color=theme_color, icon='info-sign')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8720045d9f15aa4e524c0bdf68221a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#             bottom: 20px; left: 20px; width: 200px; height: 150px;
#             background-color: white; z-index:9999; font-size:14px;
#             border:2px solid grey; padding: 10px;&quot;&gt;
# &lt;b&gt;Legenda Kategori POI:&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:purple; width:12px; height:12px; display:inline-block;&quot;&gt;&lt;/i&gt; Cultural&lt;br&gt;&lt;i style=&quot;background:grey; width:12px; height:12px; display:inline-block;&quot;&gt;&lt;/i&gt; Architectural&lt;br&gt;&lt;i style=&quot;background:orange; width:12px; height:12px; display:inline-block;&quot;&gt;&lt;/i&gt; Historical&lt;br&gt;&lt;i style=&quot;background:lightblue; width:12px; height:12px; display:inline-block;&quot;&gt;&lt;/i&gt; Transport&lt;br&gt;&lt;i style=&quot;background:green; width:12px; height:12px; display:inline-block;&quot;&gt;&lt;/i&gt; Park&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8720045d9f15aa4e524c0bdf68221a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8720045d9f15aa4e524c0bdf68221a0 = L.map(
#                 &quot;map_c8720045d9f15aa4e524c0bdf68221a0&quot;,
#                 {
#                     center: [35.304706625, 34.640665875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8aa5b617f3880a01cc2a48f07a4d174 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8aa5b617f3880a01cc2a48f07a4d174.addTo(map_c8720045d9f15aa4e524c0bdf68221a0);
#
#
#             var marker_59a350afd76997db5adcc44986aec5c2 = L.marker(
#                 [47.50194, 19.03417],
#                 {
# }
#             ).addTo(map_c8720045d9f15aa4e524c0bdf68221a0);
#
#
#             var icon_d0a41ce949ae533d963afcc47c956fc5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_59a350afd76997db5adcc44986aec5c2.setIcon(icon_d0a41ce949ae533d963afcc47c956fc5);
#
#
#         var popup_37819cfedb732e00f389022fc003d578 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_2b97f66f7d7ace5bdd1db4c8782fa49d = $(`&lt;div id=&quot;html_2b97f66f7d7ace5bdd1db4c8782fa49d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nama:&lt;/b&gt; Matthias_Church&lt;br&gt;&lt;b&gt;Kota:&lt;/b&gt; Budapest&lt;br&gt;&lt;b&gt;Tema:&lt;/b&gt; Cultural&lt;br&gt;&lt;b&gt;Kunjungan:&lt;/b&gt; 1584&lt;/div&gt;`)[0];
#                 popup_37819cfedb732e00f389022fc003d578.setContent(html_2b97f66f7d7ace5bdd1db4c8782fa49d);
#
#
#
#         marker_59a350afd76997db5adcc44986aec5c2.bindPopup(popup_37819cfedb732e00f389022fc003d578)
#         ;
#
#
#
#
#             marker_59a350afd76997db5adcc44986aec5c2.bindTooltip(
#                 `&lt;div&gt;
#                      Matthias_Church (1584 kunjungan)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_af05a96472296fef8ff609dbfe74d59c = L.marker(
#                 [28.524382, 77.18543],
#                 {
# }
#             ).addTo(map_c8720045d9f15aa4e524c0bdf68221a0);
#
#
#             var icon_11905ef1fd9c0d7b8703cf81e1a65430 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;grey&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_af05a96472296fef8ff609dbfe74d59c.setIcon(icon_11905ef1fd9c0d7b8703cf81e1a65430);
#
#
#         var popup_19048e0850d1f0e2926d9e77a84aa8ae = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_4728bfe3b1b1ac9956cdc5299a5f92db = $(`&lt;div id=&quot;html_4728bfe3b1b1ac9956cdc5299a5f92db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Nama:&lt;/b&gt; Qutb_complex&lt;br&gt;&lt;b&gt;Kota:&lt;/b&gt; Delhi&lt;br&gt;&lt;b&gt;Tema:&lt;/b&gt; Architectural&lt;br&gt;&lt;b&gt;Kunjungan:&lt;/b&gt; 709&lt;/div&gt;`)[0];
#                 popup_19048e0850d1f0e2926d9e77a84aa8ae.setContent(html_4728bfe3b1b1ac9956cdc5299a5f92db);
#
#
#
#         marker_af05a96472296fef8ff609dbfe74d59c.bindPopup(popup_19048e0850d1f0e2926d9e77a84aa8ae)
#         ;
#
#
#
#
#             marker_af05a96472296fef8ff609dbfe74d59c.bindTooltip(
#                 `&lt;div&gt;
#                      Qutb_complex (709 kunju
